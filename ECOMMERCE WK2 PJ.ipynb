# %% [markdown]
# ## Problem Statement
#     A company is looking to regulate over-stocking and under-stocking products to meet the exact needs of their customers. Therefore they want to identify product categories with the highest potential customer demand by analyzing key indicators such as price ranges, review volumes, and average customer ratings. This insight will help prioritize high-performing categories for marketing, inventory planning, or strategic investment.
# ## Task
#     Your task is to approach market demand from a value and pricing perspective, asking: which product offers the most from the consumer’s point of view? You could estimate the average price per product for each product. Then calculate the ratio of average rating to price — this can be used as a simple signal of perceived value (e.g., products that are low-priced but highly rated may reflect high demand and satisfaction).
# ## Hypothesis:
#     Product categories with higher review volume, competitive pricing, and strong average ratings are more likely to exhibit high customer demand.
# ##  Analysis Plan:
# - Data Cleaning & Preparation
# - Feature Engineering
# - Aggregation
# - Scoring or Ranking
# - Visualization
# - Recommendation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# %%
ecommerce = pd.read_excel('ecomm.xlsx')

# %%
ecommerce.tail(20)
# Out:
#            id                                       product_name  \
# 2002     2002  Tresemme Nourish & Relenish Hair Shampoo - 600 Ml
# 2003     2003           Stainless Steel Tea Strainer Set - 3 Pcs
# 2004     2004       Mesery Bundle Of Six Solid Slip On Underwear
# 2005     2005  Defacto Man Comfort Fit Crew Neck Short Sleeve...
# 2006     2006  L'Oreal Paris Prodigy Ammonia Free Hair Color ...
# 2007     2007   American Eagle AE Everyday Plaid Button-Up Shirt
# 2008     2008  SHEGLAM Glow Bloom Liquid Highlighter-Tea Cake...
# 2009     2009  Dice - Set Of (2) 100% Cotton Half Sleeve - White
# 2010     2010  Silicone Cushioned Syrup For Cracked Feet For ...
# 2011     2011    Eva Skin Clinic Collagen Sheet Mask ( 3 sheets)
# 2012     2012            Penduline Hair Cream For Babies - 150ml
# 2013     2013         Desert Sportive Lace-Up Sneakers For Women
# 2014     2014                         Slippers For Women - Black
# 2015     2015  Glysolid Shower and Care – Wild Rose Milk – 300ml
# 2016     2016  Dry Post Super Absorbent Postpartum Pads, 2 Pc...
# 2017     2017  Roto Liquid Ball Pen - Pack Of 36 - Blue Black...
# 2018     2018                    American Eagle Boyfriend Jogger
# 2019     2019  Malika - (6) Underwear Brief Basic With Underw...
# 2020     2020  Defacto Woman Fitted Crew Neck Knitted Short S...
# 2021  _x001A_                                                NaN
#
#                         price          reviews_count             avg_rate
# 2002               EGP 169.00   462 verified ratings                4.5/5
# 2003                EGP 49.99    37 verified ratings                3.8/5
# 2004  EGP 191.00 - EGP 200.00  2034 verified ratings                4.4/5
# 2005             EGP 1,169.00                    NaN                  NaN
# 2006               EGP 247.75    77 verified ratings                4.5/5
# 2007               EGP 600.00     7 verified ratings                4.3/5
# 2008               EGP 289.99    32 verified ratings                4.8/5
# 2009               EGP 175.00    11 verified ratings                4.5/5
# 2010               EGP 117.81   181 verified ratings                4.2/5
# 2011                EGP 85.50    34 verified ratings                4.3/5
# 2012                EGP 94.00    22 verified ratings                4.3/5
# 2013               EGP 279.00    11 verified ratings                4.3/5
# 2014               EGP 119.00    28 verified ratings                3.2/5
# 2015                EGP 37.15    89 verified ratings                4.4/5
# 2016               EGP 108.00    48 verified ratings                4.7/5
# 2017               EGP 144.85    28 verified ratings                4.7/5
# 2018               EGP 600.00     6 verified ratings  2025-05-05 00:00:00
# 2019               EGP 189.00   109 verified ratings  2025-05-04 00:00:00
# 2020               EGP 599.00     2 verified ratings  2025-05-03 00:00:00
# 2021                      NaN                    NaN                  NaN

# %%
ecommerce_copy = ecommerce.copy ()

# %% [markdown]
# ## Data Exploration

# %%
ecommerce.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2022 entries, 0 to 2021
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             2022 non-null   object
#  1   product_name   2019 non-null   object
#  2   price          2019 non-null   object
#  3   reviews_count  1111 non-null   object
#  4   avg_rate       704 non-null    object
# dtypes: object(5)
# memory usage: 79.1+ KB

# %%
ecommerce.describe()
# Out:
#           id                                       product_name      price  \
# count   2022                                               2019       2019
# unique  2022                                               1873       1332
# top        1  Fashion Blue light blocking men and women anti...  EGP 99.00
# freq       1                                                  5         22
#
#                                             reviews_count             avg_rate
# count                                                1111                  704
# unique                                                170                   27
# top     This seller does not have enough history for u...  2025-05-05 00:00:00
# freq                                                  409                  148

# %% [markdown]
# ## Data Dictionary
#     -id: Unique product ID
#     -product_name: Name of the product
#     -price: Product price
#     -reviews_count: Number of customer reviews(signal demand or popularity)
#     -avg_rate: Average rating(signal of satisfaction)

# %% [markdown]
# ## Data Cleaning

# %%
ecommerce.isnull().sum()
# Out:
# id                  0
# product_name        3
# price               3
# reviews_count     911
# avg_rate         1318
# dtype: int64

# %%
ecommerce.dropna(inplace=True)

# %%
ecommerce.isnull().sum()
# Out:
# id               0
# product_name     0
# price            0
# reviews_count    0
# avg_rate         0
# dtype: int64

# %%
ecommerce.tail(5)
# Out:
#         id                                       product_name       price  \
# 2016  2016  Dry Post Super Absorbent Postpartum Pads, 2 Pc...  EGP 108.00
# 2017  2017  Roto Liquid Ball Pen - Pack Of 36 - Blue Black...  EGP 144.85
# 2018  2018                    American Eagle Boyfriend Jogger  EGP 600.00
# 2019  2019  Malika - (6) Underwear Brief Basic With Underw...  EGP 189.00
# 2020  2020  Defacto Woman Fitted Crew Neck Knitted Short S...  EGP 599.00
#
#              reviews_count             avg_rate
# 2016   48 verified ratings                4.7/5
# 2017   28 verified ratings                4.7/5
# 2018    6 verified ratings  2025-05-05 00:00:00
# 2019  109 verified ratings  2025-05-04 00:00:00
# 2020    2 verified ratings  2025-05-03 00:00:00

# %%
def fix_avg_rate(value):
    if isinstance(value, pd.Timestamp):
      
        return "4.7/5"
    elif isinstance(value, (int, float)):
        return f"{value}/5"
    elif isinstance(value, str) and value.strip() == "":
        return "N/A"
    else:
        return value

ecommerce['avg_rate'] = ecommerce['avg_rate'].apply(fix_avg_rate)

print(ecommerce[['avg_rate']].tail())
# Out:
#                  avg_rate
# 2016                4.7/5
# 2017                4.7/5
# 2018  2025-05-05 00:00:00
# 2019  2025-05-04 00:00:00
# 2020  2025-05-03 00:00:00

# %% [markdown]
# ## Exploratory Data Analysis

# %%
male_keywords = ['men', 'boy', 'male', 'gent', 'man']
female_keywords = ['women', 'girl', 'female', 'lady', 'woman', 'postpartum', 'sandals', 'lip gloss', 'Feminine', 'Maternity']

# %%
def classify_gender(product_name):
    name = product_name.lower()
    if any(word in name for word in male_keywords):
        return "Male"
    elif any(word in name for word in female_keywords):
        return "Female"
    else:
        return "Unisex"

# %%
ecommerce['gender_category'] = ecommerce['product_name'].apply(classify_gender)

# %%
ecommerce.head(5)
# Out:
#   id                                       product_name  \
# 0  1         Dice - Bundle Of (6) Boxers For Men & Boys
# 1  2  Care & More Soft Cream With Glycerin - Strawbe...
# 2  3  NIVEA Antiperspirant Spray for Women, 48h Prot...
# 3  4  NIVEA MEN MEN Antiperspirant Spray for Men, 48...
# 4  5  NIVEA MEN Antiperspirant Spray for Men, 48h Pr...
#
#                      price          reviews_count avg_rate gender_category
# 0  EGP 329.99 - EGP 399.99    46 verified ratings    3.9/5            Male
# 1                EGP 29.00   515 verified ratings    4.2/5          Unisex
# 2               EGP 103.75   554 verified ratings    4.4/5            Male
# 3                EGP 95.00  1066 verified ratings    4.4/5            Male
# 4               EGP 103.75  1119 verified ratings    4.5/5            Male

# %%
filtered_reviews = ecommerce[['product_name', 'gender_category', 'reviews_count']].sort_values(
    by=['gender_category', 'reviews_count'], ascending=[True, False])

filtered_reviews.reset_index(drop=True).head(5)
# Out:
#                                         product_name gender_category  \
# 0   ADIDAS LZX05 Adilette Aqua Swim Sandals/Slippers          Female
# 1              Summer Pajamas For Girls_Multicoloure          Female
# 2  Maybelline New York Maybelline Lifter Lip Glos...          Female
# 3  Maybelline New York Maybelline Lifter Lip Glos...          Female
# 4              Dice - Set Of (6) Girl's Brief Undies          Female
#
#           reviews_count
# 0   77 verified ratings
# 1    7 verified ratings
# 2  594 verified ratings
# 3  491 verified ratings
# 4   48 verified ratings

# %%
ecommerce.head()
# Out:
#   id                                       product_name  \
# 0  1         Dice - Bundle Of (6) Boxers For Men & Boys
# 1  2  Care & More Soft Cream With Glycerin - Strawbe...
# 2  3  NIVEA Antiperspirant Spray for Women, 48h Prot...
# 3  4  NIVEA MEN MEN Antiperspirant Spray for Men, 48...
# 4  5  NIVEA MEN Antiperspirant Spray for Men, 48h Pr...
#
#                      price          reviews_count avg_rate gender_category
# 0  EGP 329.99 - EGP 399.99    46 verified ratings    3.9/5            Male
# 1                EGP 29.00   515 verified ratings    4.2/5          Unisex
# 2               EGP 103.75   554 verified ratings    4.4/5            Male
# 3                EGP 95.00  1066 verified ratings    4.4/5            Male
# 4               EGP 103.75  1119 verified ratings    4.5/5            Male

# %%
ecommerce['avg_rate_clean'] = ecommerce['avg_rate'].astype(str).str.extract(r'(\d+\.?\d*)')

# %%
ecommerce['avg_rate_clean'] = pd.to_numeric(ecommerce['avg_rate_clean'], errors='coerce')

# %%
ecommerce.head(8)
# Out:
#   id                                       product_name  \
# 0  1         Dice - Bundle Of (6) Boxers For Men & Boys
# 1  2  Care & More Soft Cream With Glycerin - Strawbe...
# 2  3  NIVEA Antiperspirant Spray for Women, 48h Prot...
# 3  4  NIVEA MEN MEN Antiperspirant Spray for Men, 48...
# 4  5  NIVEA MEN Antiperspirant Spray for Men, 48h Pr...
# 5  6       Skyline 32-22A - 32-inch HD LED TV - Limited
# 6  7  L'Oreal Paris Elvive Hyaluron Pure Rehydrating...
# 7  8  Listerine TOTAL CARE TARTAR PROTECT Mouthwash ...
#
#                      price          reviews_count avg_rate gender_category  \
# 0  EGP 329.99 - EGP 399.99    46 verified ratings    3.9/5            Male
# 1                EGP 29.00   515 verified ratings    4.2/5          Unisex
# 2               EGP 103.75   554 verified ratings    4.4/5            Male
# 3                EGP 95.00  1066 verified ratings    4.4/5            Male
# 4               EGP 103.75  1119 verified ratings    4.5/5            Male
# 5             EGP 4,249.00   189 verified ratings    3.7/5          Unisex
# 6                EGP 94.00    13 verified ratings    4.2/5          Unisex
# 7                EGP 79.00  1297 verified ratings    4.3/5          Unisex
#
#    avg_rate_clean
# 0             3.9
# 1             4.2
# 2             4.4
# 3             4.4
# 4             4.5
# 5             3.7
# 6             4.2
# 7             4.3

# %%
print(ecommerce['avg_rate_clean'].dtype)
# Out:
# float64

# %% [markdown]
# ## Feature Engineering

# %%
def satisfaction_level(avg_rate_clean):
    if avg_rate_clean >= 4:
        return 'SATISFIED'
    elif avg_rate_clean >= 3:
        return 'MAYBE'
    else:
        return 'NOT SATISFIED'

ecommerce['satisfaction_levels'] = ecommerce['avg_rate_clean'].apply(satisfaction_level)

print(ecommerce)
# Out:
#         id                                       product_name  \
# 0        1         Dice - Bundle Of (6) Boxers For Men & Boys
# 1        2  Care & More Soft Cream With Glycerin - Strawbe...
# 2        3  NIVEA Antiperspirant Spray for Women, 48h Prot...
# 3        4  NIVEA MEN MEN Antiperspirant Spray for Men, 48...
# 4        5  NIVEA MEN Antiperspirant Spray for Men, 48h Pr...
# ...    ...                                                ...
# 2016  2016  Dry Post Super Absorbent Postpartum Pads, 2 Pc...
# 2017  2017  Roto Liquid Ball Pen - Pack Of 36 - Blue Black...
# 2018  2018                    American Eagle Boyfriend Jogger
# 2019  2019  Malika - (6) Underwear Brief Basic With Underw...
# 2020  2020  Defacto Woman Fitted Crew Neck Knitted Short S...
#
#                         price          reviews_count             avg_rate  \
# 0     EGP 329.99 - EGP 399.99    46 verified ratings                3.9/5
# 1                   EGP 29.00   515 verified ratings                4.2/5
# 2                  EGP 103.75   554 verified ratings                4.4/5
# 3                   EGP 95.00  1066 verified ratings                4.4/5
# 4                  EGP 103.75  1119 verified ratings                4.5/5
# ...                       ...                    ...                  ...
# 2016               EGP 108.00    48 verified ratings                4.7/5
# 2017               EGP 144.85    28 verified ratings                4.7/5
# 2018               EGP 600.00     6 verified ratings  2025-05-05 00:00:00
# 2019               EGP 189.00   109 verified ratings  2025-05-04 00:00:00
# 2020               EGP 599.00     2 verified ratings  2025-05-03 00:00:00
#
#      gender_category  avg_rate_clean satisfaction_levels
# 0               Male             3.9               MAYBE
# 1             Unisex             4.2           SATISFIED
# 2               Male             4.4           SATISFIED
# 3               Male             4.4           SATISFIED
# 4               Male             4.5           SATISFIED
# ...              ...             ...                 ...
# 2016          Female             4.7           SATISFIED
# 2017          Unisex             4.7           SATISFIED
# 2018            Male          2025.0           SATISFIED
# 2019          Unisex          2025.0           SATISFIED
# 2020            Male          2025.0           SATISFIED
#
# [704 rows x 8 columns]

# %%
import re
import math

# %%
ecommerce[['min_price', 'max_price']] = ecommerce['price'].str.extract(r'EGP\s*([\d.]+)\s*-\s*EGP\s*([\d.]+)')


ecommerce['single_price'] = ecommerce['price'].str.extract(r'EGP\s*([\d.]+)')

ecommerce['min_price'] = ecommerce['min_price'].fillna(ecommerce['single_price'])
ecommerce['max_price'] = ecommerce['max_price'].fillna(ecommerce['single_price'])

ecommerce['min_price'] = pd.to_numeric(ecommerce['min_price'], errors='coerce')
ecommerce['max_price'] = pd.to_numeric(ecommerce['max_price'], errors='coerce')

ecommerce['min_price_rounded'] = ecommerce['min_price'].apply(lambda x: np.ceil(x) if pd.notna(x) else np.nan).astype('Int64')
ecommerce['max_price_rounded'] = ecommerce['max_price'].apply(lambda x: np.ceil(x) if pd.notna(x) else np.nan).astype('Int64')

print(ecommerce[['price', 'min_price_rounded', 'max_price_rounded']])
# Out:
#                         price  min_price_rounded  max_price_rounded
# 0     EGP 329.99 - EGP 399.99                330                400
# 1                   EGP 29.00                 29                 29
# 2                  EGP 103.75                104                104
# 3                   EGP 95.00                 95                 95
# 4                  EGP 103.75                104                104
# ...                       ...                ...                ...
# 2016               EGP 108.00                108                108
# 2017               EGP 144.85                145                145
# 2018               EGP 600.00                600                600
# 2019               EGP 189.00                189                189
# 2020               EGP 599.00                599                599
#
# [704 rows x 3 columns]

# %%
ecommerce.to_excel('output.xlsx', index=False)

# %%
ecommerce['reviews_num'] = ecommerce['reviews_count'].str.extract(r'(\d+)')

# %%
ecommerce['reviews_num'] = pd.to_numeric(ecommerce['reviews_num'], errors='coerce')

# %%
ecommerce['reviews_num'] = ecommerce['reviews_num'].fillna(0).astype(int)

# %%
ecommerce.head(5)
# Out:
#   id                                       product_name  \
# 0  1         Dice - Bundle Of (6) Boxers For Men & Boys
# 1  2  Care & More Soft Cream With Glycerin - Strawbe...
# 2  3  NIVEA Antiperspirant Spray for Women, 48h Prot...
# 3  4  NIVEA MEN MEN Antiperspirant Spray for Men, 48...
# 4  5  NIVEA MEN Antiperspirant Spray for Men, 48h Pr...
#
#                      price          reviews_count avg_rate gender_category  \
# 0  EGP 329.99 - EGP 399.99    46 verified ratings    3.9/5            Male
# 1                EGP 29.00   515 verified ratings    4.2/5          Unisex
# 2               EGP 103.75   554 verified ratings    4.4/5            Male
# 3                EGP 95.00  1066 verified ratings    4.4/5            Male
# 4               EGP 103.75  1119 verified ratings    4.5/5            Male
#
#    avg_rate_clean satisfaction_levels  min_price  max_price single_price  \
# 0             3.9               MAYBE     329.99     399.99       329.99
# 1             4.2           SATISFIED      29.00      29.00        29.00
# 2             4.4           SATISFIED     103.75     103.75       103.75
# 3             4.4           SATISFIED      95.00      95.00        95.00
# 4             4.5           SATISFIED     103.75     103.75       103.75
#
#    min_price_rounded  max_price_rounded  reviews_num
# 0                330                400           46
# 1                 29                 29          515
# 2                104                104          554
# 3                 95                 95         1066
# 4                104                104         1119

# %%
ecommerce.to_excel('ecommerce.xlsx', index=False)

# %%
new = pd.read_excel('ecommercee.xlsx')

# %%
new
# Out:
#        id                                       Product_name  Gender  \
# 0     473         Defacto Woman Denim Wideleg Cargo Trousers  Female
# 1    1287  Defacto Woman Regular Fit Woven Long Sleeve Bl...  Female
# 2     753       Avon Incandessence - EDP - For Women - 50 Ml  Female
# 3     918  Aula Arabic/English F2058 Full Mechanical Gami...  Unisex
# 4      23  ADIDAS DBF11 Adilette Aqua Swim Sandals/Slippe...  Female
# ..    ...                                                ...     ...
# 699  1677                  ADIDAS DSZ57 Arkd3 Backpack- Grey  Unisex
# 700   671  Energizer Accu Recharge Battery Charger Batter...  Unisex
# 701  2018                    American Eagle Boyfriend Jogger    Male
# 702  2019  Malika - (6) Underwear Brief Basic With Underw...  Unisex
# 703  2020  Defacto Woman Fitted Crew Neck Knitted Short S...    Male
#
#      Avg rate satisfaction Satisfaction_levels  Price  Cust_Reviews  \
# 0                      4.6           SATISFIED  999.0            12
# 1                      4.8           SATISFIED  999.0             4
# 2                      4.4           SATISFIED  995.0           108
# 3                      4.7           SATISFIED  990.0             3
# 4                      4.5           SATISFIED  975.0           177
# ..                     ...                 ...    ...           ...
# 699                    4.5           SATISFIED    1.0             4
# 700                    4.7           SATISFIED    1.0             3
# 701                 2025.0           SATISFIED  600.0             6
# 702                 2025.0           SATISFIED  189.0           109
# 703                 2025.0           SATISFIED  599.0             2
#
#       Demand_level
# 0       LOW DEMAND
# 1       LOW DEMAND
# 2    MEDIUM DEMAND
# 3       LOW DEMAND
# 4    MEDIUM DEMAND
# ..             ...
# 699     LOW DEMAND
# 700     LOW DEMAND
# 701     LOW DEMAND
# 702  MEDIUM DEMAND
# 703     LOW DEMAND
#
# [704 rows x 8 columns]

# %%
def classify_price(Price):
    if Price < 200:
        return "Cheap"
    elif Price <= 500:
        return "Affordable"
    else:
        return "Expensive"

new['Price_Level'] = new['Price'].apply(classify_price)

# %%
new
# Out:
#        id                                       Product_name  Gender  \
# 0     473         Defacto Woman Denim Wideleg Cargo Trousers  Female
# 1    1287  Defacto Woman Regular Fit Woven Long Sleeve Bl...  Female
# 2     753       Avon Incandessence - EDP - For Women - 50 Ml  Female
# 3     918  Aula Arabic/English F2058 Full Mechanical Gami...  Unisex
# 4      23  ADIDAS DBF11 Adilette Aqua Swim Sandals/Slippe...  Female
# ..    ...                                                ...     ...
# 699  1677                  ADIDAS DSZ57 Arkd3 Backpack- Grey  Unisex
# 700   671  Energizer Accu Recharge Battery Charger Batter...  Unisex
# 701  2018                    American Eagle Boyfriend Jogger    Male
# 702  2019  Malika - (6) Underwear Brief Basic With Underw...  Unisex
# 703  2020  Defacto Woman Fitted Crew Neck Knitted Short S...    Male
#
#      Avg rate satisfaction Satisfaction_levels  Price  Cust_Reviews  \
# 0                      4.6           SATISFIED  999.0            12
# 1                      4.8           SATISFIED  999.0             4
# 2                      4.4           SATISFIED  995.0           108
# 3                      4.7           SATISFIED  990.0             3
# 4                      4.5           SATISFIED  975.0           177
# ..                     ...                 ...    ...           ...
# 699                    4.5           SATISFIED    1.0             4
# 700                    4.7           SATISFIED    1.0             3
# 701                 2025.0           SATISFIED  600.0             6
# 702                 2025.0           SATISFIED  189.0           109
# 703                 2025.0           SATISFIED  599.0             2
#
#       Demand_level Price_Level
# 0       LOW DEMAND   Expensive
# 1       LOW DEMAND   Expensive
# 2    MEDIUM DEMAND   Expensive
# 3       LOW DEMAND   Expensive
# 4    MEDIUM DEMAND   Expensive
# ..             ...         ...
# 699     LOW DEMAND       Cheap
# 700     LOW DEMAND       Cheap
# 701     LOW DEMAND   Expensive
# 702  MEDIUM DEMAND       Cheap
# 703     LOW DEMAND   Expensive
#
# [704 rows x 9 columns]

# %%
def classify_category(name):
    name = name.lower()
    if any(word in name for word in ['phone', 'laptop', 'keyboard', 'mouse', 'headphone', 'batteries', 'torch','oraimo']):
        return 'Electronics'
    elif any(word in name for word in ['sandal', 'slipper', 'shoe', 'sneaker', 'boot']):
        return 'Footwear'
    elif any(word in name for word in ['aqua', 'swim', 'bikini', 'beach', 'swimsuit']):
        return 'Beach clothing'
    elif any(word in name for word in ['foundation', 'powder', 'lipgloss', 'mascara', 'maybelline', 'concealer']):
        return 'Makeups'
    elif any(word in name for word in ['trouser', 'shirt', 'dress', 'jacket', 'jean', 'blouse']):
        return 'Clothing'
    elif any(word in name for word in ['perfume', 'edp', 'fragrance']):
        return 'Fragrance'
    else:
        return 'Other'

new['Product_Category'] = new['Product_name'].apply(classify_category)

# Preview the result
new[['Product_name', 'Product_Category']].head()
# Out:
#                                         Product_name Product_Category
# 0         Defacto Woman Denim Wideleg Cargo Trousers         Clothing
# 1  Defacto Woman Regular Fit Woven Long Sleeve Bl...         Clothing
# 2       Avon Incandessence - EDP - For Women - 50 Ml        Fragrance
# 3  Aula Arabic/English F2058 Full Mechanical Gami...      Electronics
# 4  ADIDAS DBF11 Adilette Aqua Swim Sandals/Slippe...         Footwear

# %%
new.to_excel('new.xlsx', index=False)
